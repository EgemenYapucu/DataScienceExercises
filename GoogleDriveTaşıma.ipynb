# %% [markdown]
# <a href="https://colab.research.google.com/github/EgemenYapucu/DataScienceExercises/blob/main/GoogleDriveTa%C5%9F%C4%B1ma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pydrive
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import csv
import shutil

# CSV dosyası yolunu belirtin
csv_file_path = '/content/drive/MyDrive/metadata.csv'

# Hedef klasör yolu
target_folder_path = '/content/drive/MyDrive/RealDataset'

source_folder_path = '/content/drive/MyDrive/FaceData'

# CSV dosyasını okuyun ve dosya adlarını bir liste olarak alın
file_names = []
with open(csv_file_path, 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        file_names.extend(row)

# Dosyaları hedef klasöre taşıma
for file_name in file_names:
    source_file_path = os.path.join(source_folder_path, file_name)
    target_file_path = os.path.join(target_folder_path, file_name)
    try:
        shutil.move(source_file_path, target_file_path)
        print('Dosya taşındı: %s' % file_name)
    except FileNotFoundError:
        print('Dosya bulunamadı: %s' % file_name)
    except shutil.Error:
        print('Dosya taşıma hatası: %s' % file_name)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Dosya bulunamadı: id38_id34_0006.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id34_0007.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id34_0008.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id34_0009.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0000.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0001.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0002.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0003.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0004.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0005.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0006.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0007.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id35_0009.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id37_0000.mp4
# Dosya bulunamadı: FAKE
# Dosya bulunamadı: id38_id37_0001.mp4
# ...
